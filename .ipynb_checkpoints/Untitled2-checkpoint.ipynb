# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data.129.2.180.42.269.14.45.12.txt', sep=" ", header=None)
data = data.drop(0, axis=1).drop(3, axis=1)
data.columns = ['Date', 'Sigma']

# %%
data.columns
# Out:
# Index(['Date', 'Sigma'], dtype='object')

# %%
data['Sigma'].isna().value_counts()
# Out:
# False    860
# True      40
# Name: Sigma, dtype: int64

# %%
data[data['Sigma'].isna()]
df = data.loc[data['Sigma'].isna() == False]

# %%
df
# Out:
#             Date  Sigma
# 36   1951.000000    2.5
# 37   1951.083333    1.5
# 38   1951.166667   -0.2
# 39   1951.250000   -0.5
# 40   1951.333333   -1.1
# ..           ...    ...
# 891  2022.250000    2.8
# 892  2022.333333    2.4
# 893  2022.416667    2.8
# 894  2022.500000    1.3
# 895  2022.583333    1.7
#
# [860 rows x 2 columns]

# %%
x1 = df['Sigma'][20:]

# %%
x2 = df['Sigma'][11:851]

# %%
x3 = df['Sigma'][:840]

# %%
x3.shape
# Out:
# (840,)

# %%
ax = plt.figure().add_subplot(projection='3d')

ax.plot(x1, x2, x3, lw=0.5)
ax.set_xlabel("X1 Axis")
ax.set_ylabel("X2 Axis")
ax.set_zlabel("X3 Axis")
ax.set_title("Climate Data")

plt.show()

# %%
coords = np.vstack((x1, x2, x3))
print(coords.shape)
U, s, V = np.linalg.svd(coords)
U.shape, s.shape, V.shape
# Out:
# (3, 840)
# ((3, 3), (3,), (840, 840))

# %%
print(np.vstack((x1, x2, x3)).shape)
basis = np.vstack((U[:,0], U[:,1], U[:,2]))
print(U)
print(basis)
coordssvd = np.linalg.solve(U, coords)
coordssvd
# Out:
# (3, 840)
# [[-0.7277786   0.16990731  0.66443195]
#  [-0.68577734 -0.19005618 -0.70255824]
#  [ 0.00690962 -0.96695923  0.2548374 ]]
# [[-0.7277786  -0.68577734  0.00690962]
#  [ 0.16990731 -0.19005618 -0.96695923]
#  [ 0.66443195 -0.70255824  0.2548374 ]]
# array([[ 1.1313183 ,  0.60236329,  0.68439542, ..., -2.92376293,
#         -1.76144441, -2.31373851],
#        [-2.25729359, -1.0634102 ,  0.38344803, ..., -0.54489996,
#         -1.07084307, -2.91612516],
#        [ 1.21439061,  1.83475263,  0.65159076, ...,  1.15095367,
#          0.30101279,  0.76995333]])

# %%
ax = plt.figure().add_subplot(projection='3d')

ax.scatter(coordssvd[0], coordssvd[1], coordssvd[2], lw=0.5, alpha=.1)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")

ax = plt.figure().add_subplot(projection='3d')

ax.plot(coordssvd[0], coordssvd[1], coordssvd[2], lw=0.5, alpha=.1)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
# Out:
# Text(0.5, 0, 'Z Axis')

# %%
xs = []
for i in range(10):
    xs.append(df['Sigma'][i*10:860-(10-i)*10])

# %%
xs
# Out:
# [36     2.5
#  37     1.5
#  38    -0.2
#  39    -0.5
#  40    -1.1
#        ...
#  791    0.1
#  792    2.4
#  793    0.1
#  794   -1.5
#  795    1.3
#  Name: Sigma, Length: 760, dtype: float64,
#  46    -1.3
#  47    -1.2
#  48    -1.5
#  49    -1.0
#  50     0.9
#        ...
#  801   -1.0
#  802   -1.5
#  803   -0.9
#  804   -1.4
#  805    0.4
#  Name: Sigma, Length: 760, dtype: float64,
#  56    -0.4
#  57     0.6
#  58     0.0
#  59    -2.0
#  60     0.5
#        ...
#  811   -2.4
#  812   -2.7
#  813   -2.8
#  814   -0.8
#  815   -0.9
#  Name: Sigma, Length: 760, dtype: float64,
#  66    -0.0
#  67    -2.0
#  68    -2.1
#  69     0.1
#  70    -0.5
#        ...
#  821    1.1
#  822    0.7
#  823    1.2
#  824    2.0
#  825   -0.4
#  Name: Sigma, Length: 760, dtype: float64,
#  76     0.8
#  77     0.2
#  78     0.7
#  79     1.8
#  80     0.3
#        ...
#  831   -0.3
#  832    0.4
#  833   -0.7
#  834    1.3
#  835    0.9
#  Name: Sigma, Length: 760, dtype: float64,
#  86     1.1
#  87    -0.2
#  88     1.7
#  89     2.2
#  90     2.6
#        ...
#  841   -0.8
#  842    2.4
#  843    0.8
#  844    0.6
#  845   -0.2
#  Name: Sigma, Length: 760, dtype: float64,
#  96     2.2
#  97     2.7
#  98     2.2
#  99     1.5
#  100    2.3
#        ...
#  851    1.7
#  852   -0.1
#  853   -2.3
#  854   -0.5
#  855    0.2
#  Name: Sigma, Length: 760, dtype: float64,
#  106    0.2
#  107    1.8
#  108    1.0
#  109   -0.1
#  110    0.3
#        ...
#  861   -0.6
#  862   -1.4
#  863   -0.9
#  864    0.3
#  865   -0.1
#  Name: Sigma, Length: 760, dtype: float64,
#  116   -1.5
#  117    0.1
#  118   -1.6
#  119   -0.5
#  120   -3.1
#        ...
#  871    1.8
#  872    1.5
#  873    0.8
#  874    1.1
#  875    3.0
#  Name: Sigma, Length: 760, dtype: float64,
#  126    0.7
#  127    1.5
#  128   -0.5
#  129    0.1
#  130   -0.7
#        ...
#  881    0.7
#  882    2.3
#  883    1.0
#  884    1.3
#  885    1.2
#  Name: Sigma, Length: 760, dtype: float64]

# %%
plt.scatter(x1, x2, alpha=.1)

# %%
plt.plot(x1)

# %%
coords = np.vstack((xs[0], xs[1], xs[3], xs[4], xs[5], xs[6], xs[7], xs[8], xs[9]))
print(coords.shape)
U, s, V = np.linalg.svd(coords)
U.shape, s.shape, V.shape
print(np.vstack((x1, x2, x3)).shape)
basis = np.vstack((U[:,0], U[:,1], U[:,2]))
print(U)
print(basis)
coordssvd = np.linalg.solve(U, coords)
coordssvd
# Out:
# (9, 760)
# (3, 840)
# [[-0.15158309 -0.53941634  0.28630302  0.23024109  0.09530375  0.42567151
#    0.50962219 -0.04886436 -0.3141507 ]
#  [-0.41531762 -0.34332696 -0.37126309  0.02351496  0.12827187  0.42136965
#   -0.43877422  0.28385349  0.32271809]
#  [ 0.41355123 -0.22576508 -0.13663124  0.60766711  0.059519   -0.31180415
#   -0.05574211  0.53058637 -0.06844467]
#  [ 0.363706   -0.30157613 -0.45390362 -0.06732785  0.46746545 -0.09270113
#    0.15573471 -0.51273123  0.22791267]
#  [ 0.27009543 -0.34548465 -0.0219025  -0.72144909  0.04100607 -0.06467516
#   -0.09704404  0.36195182 -0.37473893]
#  [-0.02254971 -0.49232125  0.11818205 -0.09140481 -0.62994653 -0.30947285
#    0.10459824 -0.09622418  0.47115125]
#  [-0.12368435 -0.00822663 -0.63782465  0.11539951 -0.48935906  0.00380797
#    0.00281801 -0.21423073 -0.52830639]
#  [ 0.4135481   0.27472993 -0.23553464 -0.10524886 -0.26575796  0.52676006
#    0.41507822  0.27618804  0.30045687]
#  [ 0.49137286 -0.10933669  0.28063169  0.13930446 -0.20924469  0.3974784
#   -0.5724908  -0.33193585 -0.09348146]]
# [[-0.15158309 -0.41531762  0.41355123  0.363706    0.27009543 -0.02254971
#   -0.12368435  0.4135481   0.49137286]
#  [-0.53941634 -0.34332696 -0.22576508 -0.30157613 -0.34548465 -0.49232125
#   -0.00822663  0.27472993 -0.10933669]
#  [ 0.28630302 -0.37126309 -0.13663124 -0.45390362 -0.0219025   0.11818205
#   -0.63782465 -0.23553464  0.28063169]]
# array([[ 0.39831756, -0.0424758 , -0.58206521, ...,  1.80176277,
#          3.338654  ,  1.58286098],
#        [-3.09689247, -1.41742763, -1.17767975, ...,  1.1690402 ,
#          0.64267019, -0.35524339],
#        [ 1.49336362,  0.63023372,  0.29030827, ...,  0.89344758,
#         -0.93087023, -0.40821858],
#        ...,
#        [ 1.06962014,  0.92326161,  0.47238915, ..., -0.29122143,
#         -0.45651061,  1.24774959],
#        [-1.40438492, -2.76573566, -1.97568938, ...,  1.32796024,
#          0.143828  , -0.26364595],
#        [-1.02004381, -0.39008772, -0.6807944 , ..., -1.32461306,
#         -0.2311164 ,  0.96439213]])

# %%
ax = plt.figure().add_subplot(projection='3d')

ax.plot(coordssvd[0], coordssvd[1], coordssvd[2], lw=0.5, alpha=1)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
# Out:
# Text(0.5, 0, 'Z Axis')
